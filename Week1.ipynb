# %% [markdown]
# <a href="https://colab.research.google.com/github/Fadillah-Dama/PCVK_Ganjil_26/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://picsum.photos/id/237/800/300"]

# baca dan tampilkan image
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print("\n")

  # variabel
  tinggi = image_2.shape[0]
  lebar = image_2.shape[1]
  miring = (tinggi**2 + lebar**2)**(1/2)
  print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
  print("panjang diagonal image = ", miring)
  cv2_imshow(image_2)

  # membuat kotak
  top_left = (50, 50)
  bottom_right = (100, 100)
  color = (255, 255, 255)
  thickness = -1

  cv.rectangle(image_2, top_left, bottom_right, color, thickness)

  cv2_imshow(image_2)


  # membuat garis horizontal di tengah image
  # panjang = 200
  # tengah = int(lebar / 2)

  # awal = tengah - int(panjang / 2)
  # akhir = tengah + int(panjang / 2)
  # panjang = 200
  # for y in range (awal, akhir):
  #   image_2[int((tinggi)/2), y] = [255, 255, 255]

  # final_frame = cv.hconcat((image, image_2))
  # cv2_imshow(final_frame)

  # # Garis diagonal pertama
  # cv.line(image_2, (0, 0), (lebar - 1, tinggi - 1), (255, 255, 255), 1)

  # # Garis diagonal kedua
  # cv.line(image_2, (lebar - 1, 0), (0, tinggi - 1), (255, 255, 255), 1)

  # final_frame = cv.hconcat((image, image_2))

  # cv2_imshow(final_frame)

  # membuat garis menyilang miring
  # # Garis dari kiri atas ke kanan bawah
  # for z in range(min(tinggi, lebar)):
  #     image_2[z, z] = [255, 255, 255]

  # # Garis dari kanan atas ke kiri bawah
  # for z in range(min(tinggi, lebar)):
  #     image_2[z, lebar - 1 - z] = [255, 255, 255]

  # final_frame = cv.hconcat((image, image_2))
  # cv2_imshow(final_frame)



  # # membuat garis horizontal di tengah image
  # for y in range (lebar):
  #   image_2[int((tinggi)/2), y] = [255, 255, 255]

  # final_frame = cv.hconcat((image, image_2))
  # cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# resolusi image: tinggi x lebar =  276  x  400
# panjang diagonal image =  485.9794234327211
# <PIL.Image.Image image mode=RGB size=400x276>
# <PIL.Image.Image image mode=RGB size=400x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# resolusi image: tinggi x lebar =  286  x  400
# panjang diagonal image =  491.7275668497751
# <PIL.Image.Image image mode=RGB size=400x286>
# <PIL.Image.Image image mode=RGB size=400x286>
# <PIL.Image.Image image mode=RGB size=800x150>
# resolusi image: tinggi x lebar =  150  x  400
# panjang diagonal image =  427.20018726587654
# <PIL.Image.Image image mode=RGB size=400x150>
# <PIL.Image.Image image mode=RGB size=400x150>
